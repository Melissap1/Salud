# %% [markdown]
# # <font color='056938'> **Librerias** </font>

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import sys
import os

# %%
drive.mount('/content/drive')
#Define la parte del directorio que quieres trabajar
path = "/content/drive/MyDrive/Mod2/Salud"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Ruta al archivo
ruta = '/content/drive/MyDrive/Mod2/Salud/data/df_limpia.xlsx'

# Leer excel
df = pd.read_excel(ruta)
df
# Out:
#      Embarazos  Glucosa  Presión Sanguínea  Espesor de la Piel    Insulina  \
# 0            6    148.0               72.0            35.00000  155.548223
# 1            1     85.0               66.0            29.00000  155.548223
# 2            8    183.0               64.0            29.15342  155.548223
# 3            1     89.0               66.0            23.00000   94.000000
# 4            0    137.0               40.0            35.00000  168.000000
# ..         ...      ...                ...                 ...         ...
# 763         10    101.0               76.0            48.00000  180.000000
# 764          2    122.0               70.0            27.00000  155.548223
# 765          5    121.0               72.0            23.00000  112.000000
# 766          1    126.0               60.0            29.15342  155.548223
# 767          1     93.0               70.0            31.00000  155.548223
#
#       IMC  Función de Pedigrí de Diabetes  Edad  Diagnostico
# 0    33.6                        0.627000    50            1
# 1    26.6                        0.351000    31            0
# 2    23.3                        0.672000    32            1
# 3    28.1                        0.167000    21            0
# 4    43.1                        0.416104    33            1
# ..    ...                             ...   ...          ...
# 763  32.9                        0.171000    63            0
# 764  36.8                        0.340000    27            0
# 765  26.2                        0.245000    30            0
# 766  30.1                        0.349000    47            1
# 767  30.4                        0.315000    23            0
#
# [768 rows x 9 columns]

# %%
sys.path.append(path)

from b_preprocesamiento import preparar_datos
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
X_train, X_val, X_test, y_train, y_val, y_test = preparar_datos(df)
